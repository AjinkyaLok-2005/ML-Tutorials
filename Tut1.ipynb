# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area (sq ft)')
plt.ylabel('price (US$)')
plt.scatter(df.area, df.price, color = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
d = pd.read_csv("area.csv")
d.head()
# Out:
#    area
# 0  1500
# 1  2000
# 2  2300
# 3  2500
# 4  3000

# %%
print(d.shape)
# Out:
# (16, 1)

# %%
p = reg.predict(d)

# %%
d['prices'] = p

# %%
d
# Out:
#     area        prices
# 0   1500  3.842979e+05
# 1   2000  4.521918e+05
# 2   2300  4.929281e+05
# 3   2500  5.200856e+05
# 4   3000  5.879795e+05
# 5   3330  6.327894e+05
# 6   3400  6.422945e+05
# 7   3700  6.830308e+05
# 8   4000  7.237671e+05
# 9   4550  7.984503e+05
# 10  4444  7.840568e+05
# 11  5000  8.595548e+05
# 12  5555  9.349170e+05
# 13  6000  9.953425e+05
# 14  6666  1.085777e+06
# 15  7100  1.144709e+06

# %%
d.to_csv("predicted.csv", index = False)
